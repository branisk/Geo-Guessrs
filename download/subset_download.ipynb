# %% [markdown]
# # Download a subset of Global Streetscapes data

# %% [markdown]
# This notebook demostrates how to filter the Global Streetscapes dataset to find the desired subset of data.
# As an example, we show how to filter for daytime images from Singapore, and how to prepare the input csv file for download_jpegs.py to download the required jpegs.

# %%
import pandas as pd

# %% [markdown]
# ## Load file with available points

# %%
# the city information is available in the `simplemaps.csv` file
df_all = pd.read_csv(
    "../data/simplemaps.csv"
)  # update the location of the desired csv file
# Out:
# /tmp/ipykernel_21474/651033934.py:2: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_all = pd.read_csv(

# %% [markdown]
# ## Filter based on city

# %%
#df_city = df_all[df_all["city"] == "Singapore"]
df_city = df_all.sample(10_000)

# visual confirmation the city name is unique. Otherwise there would be more than one value
df_city["country"].unique()
# Out:
# array(['Albania', 'Hungary', 'Curaçao', 'United States', 'Japan',
#        'Colombia', 'Mauritius', 'Spain', 'Peru', 'Denmark', 'Uganda',
#        'Brazil', 'Bahrain', 'Kuwait', 'Germany', 'Morocco', 'France',
#        'Canada', 'Belgium', 'Costa Rica', 'Austria', 'Lesotho', 'Cuba',
#        'Latvia', 'Taiwan', 'Greece', 'United Kingdom', 'Guatemala',
#        'Moldova', 'Croatia', 'Russia', 'Estonia', 'United Arab Emirates',
#        'Mexico', 'Portugal', 'Malaysia', 'Tanzania', 'Switzerland',
#        'Finland', 'Lithuania', 'Czechia', 'Sweden', 'Honduras',
#        'Indonesia', 'Macedonia', 'Qatar', 'Poland', 'Netherlands',
#        'Australia', 'Thailand', 'Israel', 'Reunion',
#        'Antigua And Barbuda', 'Mongolia', 'Serbia', 'Chile',
#        'Philippines', 'Uruguay', 'Turks And Caicos Islands',
#        'El Salvador', 'Angola', 'Azerbaijan', 'Ecuador', 'New Zealand',
#        'Brunei', 'Belarus', 'Saint Lucia', 'Bangladesh', 'Pakistan',
#        'Slovenia', 'Turkey', 'Senegal', 'Bosnia And Herzegovina',
#        'Montserrat', 'Kazakhstan', 'India', 'Vietnam', 'Libya', 'Ghana',
#        'Venezuela', 'Mayotte', 'Singapore', 'Grenada', 'Kosovo',
#        'Bolivia', 'Dominican Republic', 'Luxembourg', 'Argentina',
#        'Martinique', 'French Guiana', 'U.S. Virgin Islands', 'Iceland',
#        'Dominica', 'Saint Vincent And The Grenadines', 'Comoros', 'Fiji',
#        'Tajikistan', 'Hong Kong', 'Norway', 'Djibouti', 'Italy',
#        'Paraguay', 'China', 'South Africa', 'Malta', 'Sint Maarten',
#        'Algeria', 'The Bahamas', 'Ireland', 'Guadeloupe', 'Benin',
#        'Lebanon', 'Bulgaria', 'Niger', 'Jordan', 'Panama', 'Guinea',
#        'Bermuda', 'Tunisia', 'Papua New Guinea', 'Mali', 'Monaco',
#        'Slovakia', 'Nicaragua', 'Cameroon', 'Romania', 'Saint Barthelemy',
#        'Iran', 'Oman', 'West Bank', 'Kenya', 'Armenia',
#        'British Virgin Islands', 'Isle Of Man', 'Barbados', 'Belize',
#        'Sierra Leone', 'Faroe Islands', 'New Caledonia', 'Svalbard',
#        'Zambia', 'Vanuatu', 'Burkina Faso', 'Liechtenstein',
#        "Côte d'Ivoire", 'Togo', 'Montenegro', 'Puerto Rico', 'San Marino',
#        'Saint Kitts And Nevis', 'Maldives', 'Myanmar',
#        'Trinidad And Tobago', 'Cyprus', 'Botswana', 'Vatican City',
#        'Timor-Leste', 'Congo (Brazzaville)', 'Greenland', 'Turkmenistan',
#        'Solomon Islands', 'Saudi Arabia', 'Suriname', 'Burundi',
#        'Andorra', 'Congo (Kinshasa)', 'Liberia', 'Jersey',
#        'Sao Tome And Principe', 'Mozambique', 'Uzbekistan', 'Aruba',
#        'Central African Republic', 'Chad',
#        'Falkland Islands (Islas Malvinas)', 'Bhutan', 'Zimbabwe',
#        'Rwanda', 'Guyana', 'Egypt'], dtype=object)

# %% [markdown]
# ## Filter based on contexual information: lighting condition

# %%
# load contextual information
df_contextual = pd.read_csv("../data/contextual.csv")
# Out:
# /tmp/ipykernel_21474/3417365278.py:2: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_contextual = pd.read_csv("../data/contextual.csv")

# %%
# merge our filtered dataset with contextual data
df_city_merged = df_city.merge(df_contextual, on=["uuid", "source", "orig_id"])
df_city_merged["lighting_condition"].unique()
# Out:
# array(['day', 'night', 'dusk/dawn'], dtype=object)

# %%
# filter only the rows during `day`
#df_city_merged = df_city_merged[df_city_merged["lighting_condition"] == "day"]
#df_city_merged["lighting_condition"].unique()
# Out:
# array(['day'], dtype=object)

# %%
df_city_merged.shape
# Out:
# (10000, 23)

# %%
df_city_merged.columns
# Out:
# Index(['uuid', 'source', 'orig_id', 'city', 'city_ascii', 'city_id',
#        'city_lat', 'city_lon', 'country', 'iso2', 'iso3', 'admin_name',
#        'capital', 'population', 'continent', 'glare', 'lighting_condition',
#        'pano_status', 'platform', 'quality', 'reflection', 'view_direction',
#        'weather'],
#       dtype='object')

# %% [markdown]
# ## Save to csv

# %%
# keep the three required columns
df_to_download = df_city_merged[["uuid", "source", "orig_id", "city_lat", "city_lon"]]
# save the file
df_to_download.to_csv("../data/imgs/sampled.csv")
