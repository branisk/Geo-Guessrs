# %%
import os
import pandas as pd

# %%
root = 'imgs/1_10000'
d = {
    'uuid': [],
    'path': []
}
for img in os.listdir(root):
    if img != '.DS_Store':
        uuid = img.split('.')[0]
        path = root + '/' + img
        d['uuid'].append(uuid)
        d['path'].append(path)
df = pd.DataFrame.from_dict(d)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9712 entries, 0 to 9711
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   uuid    9712 non-null   object
#  1   path    9712 non-null   object
# dtypes: object(2)
# memory usage: 151.9+ KB

# %%
df
# Out:
#                                       uuid  \
# 0     78937be3-88dc-4b0d-b63b-ab80f447150b
# 1     c3dc5f3c-6600-4d00-9dda-9b96e620da25
# 2     55954b05-c6ec-42d7-81c2-57e4e4adcdb3
# 3     3b04fd28-ec17-472a-a52b-ebc7b1d4dfa8
# 4     7ef6d3eb-4bf9-4cc2-86ac-f2d50e552c23
# ...                                    ...
# 9707  d556c61f-2156-490e-b901-025507a9f6c9
# 9708  65419999-8d1e-446e-b795-fd33276be174
# 9709  f9c0e583-8393-4858-9c72-5d50a7885b2e
# 9710  1ef72806-efe3-4d36-af84-d46d09638189
# 9711  1b67b69f-1c58-4ad6-ba04-b11860846b1d
#
#                                                    path
# 0     imgs/1_10000/78937be3-88dc-4b0d-b63b-ab80f4471...
# 1     imgs/1_10000/c3dc5f3c-6600-4d00-9dda-9b96e620d...
# 2     imgs/1_10000/55954b05-c6ec-42d7-81c2-57e4e4adc...
# 3     imgs/1_10000/3b04fd28-ec17-472a-a52b-ebc7b1d4d...
# 4     imgs/1_10000/7ef6d3eb-4bf9-4cc2-86ac-f2d50e552...
# ...                                                 ...
# ...

# %%
df.iloc[0].path
# Out:
# 'imgs/1_10000/78937be3-88dc-4b0d-b63b-ab80f447150b.jpeg'

# %%
df.to_csv('img_paths.csv', index=False)
